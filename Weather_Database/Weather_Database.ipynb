# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import os

# Import the requests library.
import requests

# Import the API key.
import sys

sys.path.append("..")
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 736

# %%
# get the nearest city
print(city)
# Out:
# shenkursk

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=94059b273a81e0f90fbc80eb791ed50f

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
# Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count+= 1
        record_count=1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count+=1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]

        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | san cristobal
# Processing Record 2 of Set 1 | tasiilaq
# Processing Record 3 of Set 1 | new norfolk
# Processing Record 4 of Set 1 | vila velha
# Processing Record 5 of Set 1 | paita
# Processing Record 6 of Set 1 | kavaratti
# Processing Record 7 of Set 1 | arraial do cabo
# Processing Record 8 of Set 1 | provideniya
# Processing Record 9 of Set 1 | kruisfontein
# Processing Record 10 of Set 1 | shingu
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 1 | iqaluit
# Processing Record 17 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 1 | pucallpa
# Processing Record 19 of Set 1 | longyearbyen
# Processing Record 20 of Set 1 | korem
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | dunedin
# Processing Record 23 of Set 1 | bambous virieux
# Processing Record 24 of Set 1 | rockport
# Processing Record 25 of Set 1 | eyl
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | caborca
# Processing Record 28 of Set 1 | upernavik
# Processing Record 29 of Set 1 | shetpe
# Processing Record 30 of Set 1 | carnarvon
# Processing Record 31 of Set 1 | salym
# Processing Record 32 of Set 1 | broken hill
# Processing Record 33 of Set 1 | pangnirtung
# Processing Record 34 of Set 1 | lebu
# Processing Record 35 of Set 1 | thompson
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | nikolskoye
# Processing Record 38 of Set 1 | torbay
# Processing Record 39 of Set 1 | vila franca do campo
# Processing Record 40 of Set 1 | glazov
# Processing Record 41 of Set 1 | ugep
# Processing Record 42 of Set 1 | port hawkesbury
# Processing Record 43 of Set 1 | marzuq
# Processing Record 44 of Set 1 | lompoc
# Processing Record 45 of Set 1 | avarua
# Processing Record 46 of Set 1 | san patricio
# Processing Record 47 of Set 1 | khatanga
# Processing Record 48 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 1 | buala
# Processing Record 50 of Set 1 | sena madureira
# Processing Record 1 of Set 2 | touros
# Processing Record 2 of Set 2 | andra
# Processing Record 3 of Set 2 | bluff
# Processing Record 4 of Set 2 | coihaique
# Processing Record 5 of Set 2 | kampene
# Processing Record 6 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 2 | jamestown
# Processing Record 8 of Set 2 | ransang
# Processing Record 9 of Set 2 | mataura
# Processing Record 10 of Set 2 | meulaboh
# Processing Record 11 of Set 2 | puerto ayora
# Processing Record 12 of Set 2 | dikson
# Processing Record 13 of Set 2 | cam ranh
# Processing Record 14 of Set 2 | hobart
# Processing Record 15 of Set 2 | mar del plata
# Processing Record 16 of Set 2 | linhares
# Processing Record 17 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 2 | port hardy
# Processing Record 19 of Set 2 | saint-philippe
# Processing Record 20 of Set 2 | bac lieu
# Processing Record 21 of Set 2 | terme
# Processing Record 22 of Set 2 | yellowknife
# Processing Record 23 of Set 2 | chokurdakh
# Processing Record 24 of Set 2 | castro
# Processing Record 25 of Set 2 | laguna
# Processing Record 26 of Set 2 | cherskiy
# Processing Record 27 of Set 2 | imeni poliny osipenko
# Processing Record 28 of Set 2 | kavieng
# Processing Record 29 of Set 2 | the valley
# Processing Record 30 of Set 2 | esperance
# Processing Record 31 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 32 of Set 2 | husavik
# Processing Record 33 of Set 2 | bredasdorp
# Processing Record 34 of Set 2 | lethem
# Processing Record 35 of Set 2 | atambua
# Processing Record 36 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 2 | port elizabeth
# Processing Record 38 of Set 2 | punta de piedra
# Processing Record 39 of Set 2 | pisco
# Processing Record 40 of Set 2 | hirara
# Processing Record 41 of Set 2 | juegang
# Processing Record 42 of Set 2 | tigzirt
# Processing Record 43 of Set 2 | saint george
# Processing Record 44 of Set 2 | halden
# Processing Record 45 of Set 2 | port alfred
# Processing Record 46 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 2 | dudinka
# Processing Record 48 of Set 2 | manono
# Processing Record 49 of Set 2 | estepona
# Processing Record 50 of Set 2 | himora
# City not found. Skipping...
# Processing Record 1 of Set 3 | hermanus
# Processing Record 2 of Set 3 | kapaa
# Processing Record 3 of Set 3 | hilo
# Processing Record 4 of Set 3 | mandalgovi
# Processing Record 5 of Set 3 | rawson
# Processing Record 6 of Set 3 | saryozek
# Processing Record 7 of Set 3 | lata
# Processing Record 8 of Set 3 | okhotsk
# Processing Record 9 of Set 3 | aklavik
# Processing Record 10 of Set 3 | sisimiut
# Processing Record 11 of Set 3 | vaini
# Processing Record 12 of Set 3 | tari
# Processing Record 13 of Set 3 | cape town
# Processing Record 14 of Set 3 | ternate
# Processing Record 15 of Set 3 | kuminskiy
# Processing Record 16 of Set 3 | east london
# Processing Record 17 of Set 3 | kiunga
# Processing Record 18 of Set 3 | ponta do sol
# Processing Record 19 of Set 3 | camargo
# Processing Record 20 of Set 3 | north bend
# Processing Record 21 of Set 3 | port-gentil
# Processing Record 22 of Set 3 | lagoa
# Processing Record 23 of Set 3 | talnakh
# Processing Record 24 of Set 3 | hofn
# Processing Record 25 of Set 3 | bandarbeyla
# Processing Record 26 of Set 3 | parry sound
# Processing Record 27 of Set 3 | agadez
# Processing Record 28 of Set 3 | thunder bay
# Processing Record 29 of Set 3 | saldanha
# Processing Record 30 of Set 3 | brae
# Processing Record 31 of Set 3 | constitucion
# Processing Record 32 of Set 3 | port macquarie
# Processing Record 33 of Set 3 | myszkow
# Processing Record 34 of Set 3 | marawi
# Processing Record 35 of Set 3 | izhma
# Processing Record 36 of Set 3 | atuona
# Processing Record 37 of Set 3 | beyneu
# Processing Record 38 of Set 3 | heishan
# Processing Record 39 of Set 3 | kodiak
# Processing Record 40 of Set 3 | oil city
# Processing Record 41 of Set 3 | asekeyevo
# Processing Record 42 of Set 3 | preobrazheniye
# Processing Record 43 of Set 3 | karamea
# City not found. Skipping...
# Processing Record 44 of Set 3 | yulara
# Processing Record 45 of Set 3 | asau
# Processing Record 46 of Set 3 | makueni
# Processing Record 47 of Set 3 | ust-maya
# Processing Record 48 of Set 3 | ikwiriri
# Processing Record 49 of Set 3 | padang
# Processing Record 50 of Set 3 | anadyr
# Processing Record 1 of Set 4 | tripoli
# Processing Record 2 of Set 4 | dwarka
# Processing Record 3 of Set 4 | kajaani
# Processing Record 4 of Set 4 | santa rosa
# Processing Record 5 of Set 4 | vardo
# Processing Record 6 of Set 4 | fairbanks
# Processing Record 7 of Set 4 | gizo
# Processing Record 8 of Set 4 | hovd
# Processing Record 9 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 4 | inirida
# Processing Record 11 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 4 | sombrio
# Processing Record 13 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 4 | pontes e lacerda
# Processing Record 15 of Set 4 | bethel
# Processing Record 16 of Set 4 | ganzhou
# Processing Record 17 of Set 4 | caldwell
# Processing Record 18 of Set 4 | matara
# Processing Record 19 of Set 4 | cidreira
# Processing Record 20 of Set 4 | dubbo
# Processing Record 21 of Set 4 | sorong
# Processing Record 22 of Set 4 | sitka
# Processing Record 23 of Set 4 | samarai
# Processing Record 24 of Set 4 | nabire
# Processing Record 25 of Set 4 | nome
# Processing Record 26 of Set 4 | christchurch
# Processing Record 27 of Set 4 | yuanping
# Processing Record 28 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 4 | khorixas
# Processing Record 30 of Set 4 | huancavelica
# Processing Record 31 of Set 4 | almaznyy
# Processing Record 32 of Set 4 | maceio
# Processing Record 33 of Set 4 | puerto rico
# Processing Record 34 of Set 4 | sao joao da barra
# Processing Record 35 of Set 4 | rancharia
# Processing Record 36 of Set 4 | astana
# Processing Record 37 of Set 4 | tuktoyaktuk
# Processing Record 38 of Set 4 | vao
# Processing Record 39 of Set 4 | beidao
# Processing Record 40 of Set 4 | yar-sale
# Processing Record 41 of Set 4 | kjollefjord
# Processing Record 42 of Set 4 | mahanoro
# Processing Record 43 of Set 4 | keti bandar
# Processing Record 44 of Set 4 | vestmannaeyjar
# Processing Record 45 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 46 of Set 4 | miri
# Processing Record 47 of Set 4 | dorado
# Processing Record 48 of Set 4 | salinopolis
# Processing Record 49 of Set 4 | agadir
# Processing Record 50 of Set 4 | wahiawa
# Processing Record 1 of Set 5 | ouargaye
# Processing Record 2 of Set 5 | severo-kurilsk
# Processing Record 3 of Set 5 | westerly
# Processing Record 4 of Set 5 | lufilufi
# Processing Record 5 of Set 5 | jalu
# Processing Record 6 of Set 5 | nemuro
# Processing Record 7 of Set 5 | tiksi
# Processing Record 8 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 9 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 5 | butaritari
# Processing Record 11 of Set 5 | lungi
# Processing Record 12 of Set 5 | angoche
# Processing Record 13 of Set 5 | sompeta
# Processing Record 14 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 5 | mount gambier
# Processing Record 16 of Set 5 | pavilosta
# Processing Record 17 of Set 5 | jiaohe
# Processing Record 18 of Set 5 | aksarka
# Processing Record 19 of Set 5 | garissa
# Processing Record 20 of Set 5 | bathsheba
# Processing Record 21 of Set 5 | prince albert
# Processing Record 22 of Set 5 | cam pha
# City not found. Skipping...
# Processing Record 23 of Set 5 | pacific grove
# Processing Record 24 of Set 5 | yichun
# Processing Record 25 of Set 5 | katsuura
# Processing Record 26 of Set 5 | komsomolskiy
# Processing Record 27 of Set 5 | pemba
# Processing Record 28 of Set 5 | mehamn
# Processing Record 29 of Set 5 | nyurba
# Processing Record 30 of Set 5 | ucluelet
# Processing Record 31 of Set 5 | casper
# Processing Record 32 of Set 5 | saskylakh
# Processing Record 33 of Set 5 | stokmarknes
# Processing Record 34 of Set 5 | grindavik
# Processing Record 35 of Set 5 | nishihara
# Processing Record 36 of Set 5 | tawala
# Processing Record 37 of Set 5 | georgetown
# Processing Record 38 of Set 5 | opuwo
# Processing Record 39 of Set 5 | rio gallegos
# Processing Record 40 of Set 5 | chipinge
# Processing Record 41 of Set 5 | maisach
# Processing Record 42 of Set 5 | salta
# Processing Record 43 of Set 5 | severo-yeniseyskiy
# Processing Record 44 of Set 5 | sulangan
# Processing Record 45 of Set 5 | barrow
# Processing Record 46 of Set 5 | gobabis
# Processing Record 47 of Set 5 | victoria
# Processing Record 48 of Set 5 | senmonorom
# City not found. Skipping...
# Processing Record 49 of Set 5 | inndyr
# Processing Record 50 of Set 5 | luderitz
# Processing Record 1 of Set 6 | sur
# Processing Record 2 of Set 6 | mitsamiouli
# Processing Record 3 of Set 6 | mahebourg
# Processing Record 4 of Set 6 | olga
# Processing Record 5 of Set 6 | arman
# Processing Record 6 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 7 of Set 6 | kaitangata
# Processing Record 8 of Set 6 | poum
# Processing Record 9 of Set 6 | ushtobe
# Processing Record 10 of Set 6 | kununurra
# Processing Record 11 of Set 6 | hithadhoo
# Processing Record 12 of Set 6 | mayo
# Processing Record 13 of Set 6 | isangel
# Processing Record 14 of Set 6 | galegos
# Processing Record 15 of Set 6 | vestmanna
# Processing Record 16 of Set 6 | dukat
# Processing Record 17 of Set 6 | zhigansk
# Processing Record 18 of Set 6 | bowen
# Processing Record 19 of Set 6 | zhigalovo
# Processing Record 20 of Set 6 | warrington
# Processing Record 21 of Set 6 | ostrovnoy
# Processing Record 22 of Set 6 | jumla
# Processing Record 23 of Set 6 | bac giang
# Processing Record 24 of Set 6 | dalby
# Processing Record 25 of Set 6 | siddapur
# Processing Record 26 of Set 6 | chudniv
# Processing Record 27 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 28 of Set 6 | itoman
# Processing Record 29 of Set 6 | laharpur
# Processing Record 30 of Set 6 | richards bay
# Processing Record 31 of Set 6 | avera
# Processing Record 32 of Set 6 | portland
# Processing Record 33 of Set 6 | murgab
# Processing Record 34 of Set 6 | schwalmtal
# Processing Record 35 of Set 6 | swellendam
# Processing Record 36 of Set 6 | faya
# Processing Record 37 of Set 6 | kaeo
# Processing Record 38 of Set 6 | sao filipe
# Processing Record 39 of Set 6 | mullaitivu
# City not found. Skipping...
# Processing Record 40 of Set 6 | ambulu
# Processing Record 41 of Set 6 | port lincoln
# Processing Record 42 of Set 6 | kedrovyy
# Processing Record 43 of Set 6 | hoima
# Processing Record 44 of Set 6 | abilene
# Processing Record 45 of Set 6 | carutapera
# Processing Record 46 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 47 of Set 6 | buenaventura
# Processing Record 48 of Set 6 | chase
# Processing Record 49 of Set 6 | clyde river
# Processing Record 50 of Set 6 | leningradskiy
# Processing Record 1 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 2 of Set 7 | ilulissat
# Processing Record 3 of Set 7 | udachnyy
# Processing Record 4 of Set 7 | korla
# Processing Record 5 of Set 7 | bakaly
# Processing Record 6 of Set 7 | eureka
# Processing Record 7 of Set 7 | cap malheureux
# Processing Record 8 of Set 7 | sorland
# Processing Record 9 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 10 of Set 7 | mali
# Processing Record 11 of Set 7 | srednekolymsk
# Processing Record 12 of Set 7 | winter garden
# Processing Record 13 of Set 7 | manaure
# Processing Record 14 of Set 7 | ust-ishim
# Processing Record 15 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 7 | evensk
# Processing Record 17 of Set 7 | kotovo
# Processing Record 18 of Set 7 | qaanaaq
# Processing Record 19 of Set 7 | escalerillas
# Processing Record 20 of Set 7 | bengkulu
# Processing Record 21 of Set 7 | pilar
# Processing Record 22 of Set 7 | olafsvik
# Processing Record 23 of Set 7 | hobyo
# Processing Record 24 of Set 7 | solwezi
# Processing Record 25 of Set 7 | wuwei
# Processing Record 26 of Set 7 | ahipara
# Processing Record 27 of Set 7 | hualmay
# Processing Record 28 of Set 7 | kangaatsiaq
# Processing Record 29 of Set 7 | gremyachinsk
# Processing Record 30 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 7 | isiro
# Processing Record 32 of Set 7 | pauini
# Processing Record 33 of Set 7 | puerto leguizamo
# Processing Record 34 of Set 7 | ksenyevka
# City not found. Skipping...
# Processing Record 35 of Set 7 | josefina
# Processing Record 36 of Set 7 | ribeira grande
# Processing Record 37 of Set 7 | sola
# Processing Record 38 of Set 7 | tuatapere
# Processing Record 39 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 7 | la asuncion
# Processing Record 41 of Set 7 | ereymentau
# Processing Record 42 of Set 7 | natal
# Processing Record 43 of Set 7 | praia
# Processing Record 44 of Set 7 | contamana
# Processing Record 45 of Set 7 | comandau
# Processing Record 46 of Set 7 | geraldton
# Processing Record 47 of Set 7 | ati
# Processing Record 48 of Set 7 | sawakin
# Processing Record 49 of Set 7 | bubaque
# Processing Record 50 of Set 7 | mpongwe
# Processing Record 1 of Set 8 | ventspils
# Processing Record 2 of Set 8 | tilichiki
# Processing Record 3 of Set 8 | kennett
# Processing Record 4 of Set 8 | itarema
# Processing Record 5 of Set 8 | ogbomosho
# Processing Record 6 of Set 8 | pevek
# Processing Record 7 of Set 8 | dalbandin
# Processing Record 8 of Set 8 | acapulco
# Processing Record 9 of Set 8 | port blair
# Processing Record 10 of Set 8 | bikaner
# Processing Record 11 of Set 8 | verkhnevilyuysk
# Processing Record 12 of Set 8 | balimo
# City not found. Skipping...
# Processing Record 13 of Set 8 | klaksvik
# Processing Record 14 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 15 of Set 8 | lorengau
# Processing Record 16 of Set 8 | muros
# Processing Record 17 of Set 8 | halifax
# Processing Record 18 of Set 8 | gat
# Processing Record 19 of Set 8 | atherton
# Processing Record 20 of Set 8 | guanambi
# Processing Record 21 of Set 8 | saravena
# Processing Record 22 of Set 8 | yerbogachen
# Processing Record 23 of Set 8 | wajima
# Processing Record 24 of Set 8 | suoyarvi
# Processing Record 25 of Set 8 | henties bay
# Processing Record 26 of Set 8 | oussouye
# Processing Record 27 of Set 8 | yinchuan
# Processing Record 28 of Set 8 | norman wells
# Processing Record 29 of Set 8 | kahului
# Processing Record 30 of Set 8 | puerto colombia
# Processing Record 31 of Set 8 | bingol
# Processing Record 32 of Set 8 | nouadhibou
# Processing Record 33 of Set 8 | santiago del estero
# Processing Record 34 of Set 8 | raga
# Processing Record 35 of Set 8 | ratnagiri
# Processing Record 36 of Set 8 | shache
# Processing Record 37 of Set 8 | serebriya
# Processing Record 38 of Set 8 | bagacay
# Processing Record 39 of Set 8 | lahij
# Processing Record 40 of Set 8 | batagay-alyta
# Processing Record 41 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 42 of Set 8 | codrington
# Processing Record 43 of Set 8 | hay river
# Processing Record 44 of Set 8 | qaqortoq
# Processing Record 45 of Set 8 | tual
# Processing Record 46 of Set 8 | mayskiy
# Processing Record 47 of Set 8 | aktau
# Processing Record 48 of Set 8 | basco
# Processing Record 49 of Set 8 | guaimaca
# Processing Record 50 of Set 8 | morros
# Processing Record 1 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 2 of Set 9 | elko
# Processing Record 3 of Set 9 | manavalakurichi
# Processing Record 4 of Set 9 | cutervo
# Processing Record 5 of Set 9 | nizhniy tsasuchey
# Processing Record 6 of Set 9 | tuim
# Processing Record 7 of Set 9 | shambu
# Processing Record 8 of Set 9 | vidim
# Processing Record 9 of Set 9 | narrabri
# Processing Record 10 of Set 9 | sao paulo de olivenca
# Processing Record 11 of Set 9 | chuy
# Processing Record 12 of Set 9 | nanortalik
# Processing Record 13 of Set 9 | verkhoyansk
# Processing Record 14 of Set 9 | berlevag
# Processing Record 15 of Set 9 | seymchan
# Processing Record 16 of Set 9 | buta
# Processing Record 17 of Set 9 | souillac
# Processing Record 18 of Set 9 | san quintin
# Processing Record 19 of Set 9 | springbok
# Processing Record 20 of Set 9 | pandamatenga
# Processing Record 21 of Set 9 | rolim de moura
# City not found. Skipping...
# Processing Record 22 of Set 9 | kulhudhuffushi
# Processing Record 23 of Set 9 | praia da vitoria
# Processing Record 24 of Set 9 | kamaishi
# Processing Record 25 of Set 9 | pemangkat
# Processing Record 26 of Set 9 | sinor
# Processing Record 27 of Set 9 | guerrero negro
# Processing Record 28 of Set 9 | ferme-neuve
# Processing Record 29 of Set 9 | scottsburgh
# City not found. Skipping...
# Processing Record 30 of Set 9 | ancud
# Processing Record 31 of Set 9 | salalah
# Processing Record 32 of Set 9 | saint-francois
# Processing Record 33 of Set 9 | omsukchan
# Processing Record 34 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 35 of Set 9 | hengshan
# Processing Record 36 of Set 9 | latehar
# Processing Record 37 of Set 9 | ranong
# Processing Record 38 of Set 9 | khuzdar
# Processing Record 39 of Set 9 | borogontsy
# Processing Record 40 of Set 9 | antsla
# Processing Record 41 of Set 9 | chicama
# Processing Record 42 of Set 9 | tawkar
# City not found. Skipping...
# Processing Record 43 of Set 9 | cairo
# Processing Record 44 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 45 of Set 9 | bilma
# Processing Record 46 of Set 9 | tagbac
# Processing Record 47 of Set 9 | naron
# Processing Record 48 of Set 9 | mariental
# Processing Record 49 of Set 9 | mackay
# Processing Record 50 of Set 9 | kirakira
# Processing Record 1 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 2 of Set 10 | gladstone
# Processing Record 3 of Set 10 | staryy nadym
# Processing Record 4 of Set 10 | novikovo
# Processing Record 5 of Set 10 | chara
# Processing Record 6 of Set 10 | alora
# Processing Record 7 of Set 10 | narsaq
# Processing Record 8 of Set 10 | banepa
# Processing Record 9 of Set 10 | zhaoyuan
# Processing Record 10 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 11 of Set 10 | sakhon nakhon
# Processing Record 12 of Set 10 | makambako
# Processing Record 13 of Set 10 | pochutla
# Processing Record 14 of Set 10 | moose factory
# Processing Record 15 of Set 10 | trinidad
# Processing Record 16 of Set 10 | yangjiang
# Processing Record 17 of Set 10 | dakar
# Processing Record 18 of Set 10 | malibu
# Processing Record 19 of Set 10 | macaboboni
# City not found. Skipping...
# Processing Record 20 of Set 10 | vostok
# Processing Record 21 of Set 10 | fortuna
# Processing Record 22 of Set 10 | heihe
# Processing Record 23 of Set 10 | george town
# Processing Record 24 of Set 10 | kristiinankaupunki
# Processing Record 25 of Set 10 | la linea
# Processing Record 26 of Set 10 | yanan
# City not found. Skipping...
# Processing Record 27 of Set 10 | les cayes
# Processing Record 28 of Set 10 | port hedland
# Processing Record 29 of Set 10 | pran buri
# Processing Record 30 of Set 10 | fort saint john
# City not found. Skipping...
# Processing Record 31 of Set 10 | cabedelo
# Processing Record 32 of Set 10 | ponta delgada
# Processing Record 33 of Set 10 | cayenne
# Processing Record 34 of Set 10 | saint-pierre
# Processing Record 35 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 36 of Set 10 | beloha
# Processing Record 37 of Set 10 | kemijarvi
# Processing Record 38 of Set 10 | afonso claudio
# Processing Record 39 of Set 10 | usinsk
# Processing Record 40 of Set 10 | creemore
# Processing Record 41 of Set 10 | westport
# Processing Record 42 of Set 10 | makakilo city
# Processing Record 43 of Set 10 | flinders
# Processing Record 44 of Set 10 | carauari
# Processing Record 45 of Set 10 | tazovskiy
# Processing Record 46 of Set 10 | kysyl-syr
# Processing Record 47 of Set 10 | cabo san lucas
# Processing Record 48 of Set 10 | coahuayana
# Processing Record 49 of Set 10 | bundaberg
# Processing Record 50 of Set 10 | jaciara
# Processing Record 1 of Set 11 | petropavlovka
# Processing Record 2 of Set 11 | alta floresta
# Processing Record 3 of Set 11 | bambanglipuro
# Processing Record 4 of Set 11 | kuandian
# Processing Record 5 of Set 11 | saint-lo
# Processing Record 6 of Set 11 | shanghai
# Processing Record 7 of Set 11 | dzaoudzi
# Processing Record 8 of Set 11 | abaza
# Processing Record 9 of Set 11 | pafos
# Processing Record 10 of Set 11 | agua verde
# Processing Record 11 of Set 11 | sambava
# Processing Record 12 of Set 11 | olinda
# Processing Record 13 of Set 11 | sal rei
# Processing Record 14 of Set 11 | kon tum
# Processing Record 15 of Set 11 | sivaki
# Processing Record 16 of Set 11 | hongjiang
# Processing Record 17 of Set 11 | chernyshevskiy
# Processing Record 18 of Set 11 | ayacucho
# Processing Record 19 of Set 11 | jacareacanga
# Processing Record 20 of Set 11 | blyth
# Processing Record 21 of Set 11 | ballina
# Processing Record 22 of Set 11 | weston
# Processing Record 23 of Set 11 | khandyga
# Processing Record 24 of Set 11 | santarem
# Processing Record 25 of Set 11 | boende
# Processing Record 26 of Set 11 | muncar
# Processing Record 27 of Set 11 | kargala
# Processing Record 28 of Set 11 | manokwari
# Processing Record 29 of Set 11 | arlit
# Processing Record 30 of Set 11 | barberton
# Processing Record 31 of Set 11 | inongo
# Processing Record 32 of Set 11 | taiyuan
# Processing Record 33 of Set 11 | menongue
# Processing Record 34 of Set 11 | araouane
# Processing Record 35 of Set 11 | airai
# Processing Record 36 of Set 11 | havre-saint-pierre
# Processing Record 37 of Set 11 | honningsvag
# Processing Record 38 of Set 11 | taltal
# Processing Record 39 of Set 11 | yarovoye
# Processing Record 40 of Set 11 | road town
# Processing Record 41 of Set 11 | ust-kut
# Processing Record 42 of Set 11 | anloga
# Processing Record 43 of Set 11 | fare
# Processing Record 44 of Set 11 | kizner
# Processing Record 45 of Set 11 | kirkland lake
# Processing Record 46 of Set 11 | mount isa
# Processing Record 47 of Set 11 | san pedro
# Processing Record 48 of Set 11 | chintamani
# Processing Record 49 of Set 11 | marienburg
# Processing Record 50 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 12 | mareeba
# Processing Record 2 of Set 12 | paragominas
# Processing Record 3 of Set 12 | cocula
# Processing Record 4 of Set 12 | kyra
# Processing Record 5 of Set 12 | tessalit
# Processing Record 6 of Set 12 | irbil
# Processing Record 7 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 8 of Set 12 | gamba
# Processing Record 9 of Set 12 | la ronge
# Processing Record 10 of Set 12 | ixtapa
# Processing Record 11 of Set 12 | fuyu
# Processing Record 12 of Set 12 | peniche
# Processing Record 13 of Set 12 | boca do acre
# Processing Record 14 of Set 12 | kashary
# Processing Record 15 of Set 12 | shiloh
# Processing Record 16 of Set 12 | lesozavodsk
# Processing Record 17 of Set 12 | terrace
# Processing Record 18 of Set 12 | ust-nera
# Processing Record 19 of Set 12 | virginia beach
# Processing Record 20 of Set 12 | dabat
# Processing Record 21 of Set 12 | grand gaube
# Processing Record 22 of Set 12 | truth or consequences
# Processing Record 23 of Set 12 | tura
# Processing Record 24 of Set 12 | tawau
# Processing Record 25 of Set 12 | xichang
# Processing Record 26 of Set 12 | port shepstone
# Processing Record 27 of Set 12 | barcelos
# Processing Record 28 of Set 12 | haines junction
# Processing Record 29 of Set 12 | calvinia
# Processing Record 30 of Set 12 | iara
# Processing Record 31 of Set 12 | ostersund
# Processing Record 32 of Set 12 | jurm
# Processing Record 33 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 34 of Set 12 | shubarkuduk
# Processing Record 35 of Set 12 | luangwa
# Processing Record 36 of Set 12 | saint-augustin
# Processing Record 37 of Set 12 | abu kamal
# Processing Record 38 of Set 12 | morant bay
# Processing Record 39 of Set 12 | zyryanka
# Processing Record 40 of Set 12 | la rioja
# Processing Record 41 of Set 12 | kabinda
# Processing Record 42 of Set 12 | mutsamudu
# City not found. Skipping...
# Processing Record 43 of Set 12 | kibre mengist
# Processing Record 44 of Set 12 | sistranda
# Processing Record 45 of Set 12 | zavodoukovsk
# Processing Record 46 of Set 12 | ketchikan
# Processing Record 47 of Set 12 | adela
# Processing Record 48 of Set 12 | lavrentiya
# Processing Record 49 of Set 12 | fort nelson
# Processing Record 50 of Set 12 | luau
# Processing Record 1 of Set 13 | cascais
# Processing Record 2 of Set 13 | bonavista
# Processing Record 3 of Set 13 | hambantota
# Processing Record 4 of Set 13 | dhidhdhoo
# Processing Record 5 of Set 13 | mehran
# Processing Record 6 of Set 13 | nizhniy kuranakh
# Processing Record 7 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 13 | mount darwin
# Processing Record 9 of Set 13 | santiago
# Processing Record 10 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 11 of Set 13 | chipata
# Processing Record 12 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 13 of Set 13 | visby
# Processing Record 14 of Set 13 | mersing
# Processing Record 15 of Set 13 | vrises
# Processing Record 16 of Set 13 | shymkent
# Processing Record 17 of Set 13 | nantucket
# Processing Record 18 of Set 13 | beringovskiy
# Processing Record 19 of Set 13 | farafangana
# Processing Record 20 of Set 13 | warin chamrap
# Processing Record 21 of Set 13 | awbari
# Processing Record 22 of Set 13 | mahon
# Processing Record 23 of Set 13 | faanui
# Processing Record 24 of Set 13 | hami
# Processing Record 25 of Set 13 | tayoltita
# Processing Record 26 of Set 13 | ayutla
# Processing Record 27 of Set 13 | macau
# Processing Record 28 of Set 13 | ugoofaaru
# Processing Record 29 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 30 of Set 13 | morondava
# Processing Record 31 of Set 13 | porto belo
# Processing Record 32 of Set 13 | pasighat
# Processing Record 33 of Set 13 | saint anthony
# Processing Record 34 of Set 13 | liseleje
# Processing Record 35 of Set 13 | muroto
# Processing Record 36 of Set 13 | olavarria
# Processing Record 37 of Set 13 | tolyatti
# Processing Record 38 of Set 13 | outjo
# Processing Record 39 of Set 13 | batouri
# Processing Record 40 of Set 13 | dingle
# Processing Record 41 of Set 13 | viedma
# Processing Record 42 of Set 13 | fukue
# Processing Record 43 of Set 13 | aluksne
# Processing Record 44 of Set 13 | hazorasp
# Processing Record 45 of Set 13 | manzil salim
# Processing Record 46 of Set 13 | bagdarin
# Processing Record 47 of Set 13 | rudiskes
# Processing Record 48 of Set 13 | hamilton
# Processing Record 49 of Set 13 | portree
# Processing Record 50 of Set 13 | troitskoye
# Processing Record 1 of Set 14 | sfantu gheorghe
# Processing Record 2 of Set 14 | tarpon springs
# Processing Record 3 of Set 14 | soyo
# Processing Record 4 of Set 14 | fougamou
# Processing Record 5 of Set 14 | asfi
# Processing Record 6 of Set 14 | deputatskiy
# Processing Record 7 of Set 14 | kadykchan
# City not found. Skipping...
# Processing Record 8 of Set 14 | hasaki
# Processing Record 9 of Set 14 | ormara
# Processing Record 10 of Set 14 | kismayo
# Processing Record 11 of Set 14 | van
# Processing Record 12 of Set 14 | cartagena
# Processing Record 13 of Set 14 | tadine
# Processing Record 14 of Set 14 | santiago de cao
# Processing Record 15 of Set 14 | oranjemund
# Processing Record 16 of Set 14 | camacha
# Processing Record 17 of Set 14 | dandong
# Processing Record 18 of Set 14 | phan rang
# City not found. Skipping...
# Processing Record 19 of Set 14 | san rafael del sur
# Processing Record 20 of Set 14 | kokopo
# Processing Record 21 of Set 14 | elizabeth city
# Processing Record 22 of Set 14 | nuevo progreso
# Processing Record 23 of Set 14 | sao felix do xingu
# Processing Record 24 of Set 14 | chumikan
# Processing Record 25 of Set 14 | kropotkin
# Processing Record 26 of Set 14 | acapetahua
# Processing Record 27 of Set 14 | suixi
# Processing Record 28 of Set 14 | demba
# Processing Record 29 of Set 14 | adrar
# Processing Record 30 of Set 14 | burns lake
# Processing Record 31 of Set 14 | ewa beach
# Processing Record 32 of Set 14 | diebougou
# Processing Record 33 of Set 14 | otukpo
# Processing Record 34 of Set 14 | corinto
# Processing Record 35 of Set 14 | rocha
# Processing Record 36 of Set 14 | voi
# Processing Record 37 of Set 14 | buraydah
# Processing Record 38 of Set 14 | yaan
# Processing Record 39 of Set 14 | port keats
# Processing Record 40 of Set 14 | amahai
# Processing Record 41 of Set 14 | kurtamysh
# Processing Record 42 of Set 14 | baiyin
# Processing Record 43 of Set 14 | vanavara
# Processing Record 44 of Set 14 | kyshtovka
# Processing Record 45 of Set 14 | hare bay
# Processing Record 46 of Set 14 | puerto del rosario
# Processing Record 47 of Set 14 | omurtag
# Processing Record 48 of Set 14 | palora
# Processing Record 49 of Set 14 | kargopol
# Processing Record 50 of Set 14 | tarragona
# Processing Record 1 of Set 15 | dinagat
# Processing Record 2 of Set 15 | novyy urengoy
# Processing Record 3 of Set 15 | dauriya
# Processing Record 4 of Set 15 | ha giang
# Processing Record 5 of Set 15 | iskateley
# Processing Record 6 of Set 15 | skeldon
# Processing Record 7 of Set 15 | novyy urgal
# Processing Record 8 of Set 15 | luganville
# Processing Record 9 of Set 15 | kasempa
# Processing Record 10 of Set 15 | churapcha
# Processing Record 11 of Set 15 | rybachiy
# Processing Record 12 of Set 15 | midland
# Processing Record 13 of Set 15 | takoradi
# Processing Record 14 of Set 15 | imbituba
# Processing Record 15 of Set 15 | luanda
# Processing Record 16 of Set 15 | calama
# Processing Record 17 of Set 15 | omoa
# Processing Record 18 of Set 15 | bembereke
# Processing Record 19 of Set 15 | apt
# Processing Record 20 of Set 15 | riohacha
# Processing Record 21 of Set 15 | andevoranto
# City not found. Skipping...
# Processing Record 22 of Set 15 | baruun-urt
# Processing Record 23 of Set 15 | maghama
# City not found. Skipping...
# Processing Record 24 of Set 15 | de-kastri
# Processing Record 25 of Set 15 | tabou
# Processing Record 26 of Set 15 | angra
# City not found. Skipping...
# Processing Record 27 of Set 15 | okahandja
# Processing Record 28 of Set 15 | sarakhs
# Processing Record 29 of Set 15 | nampula
# Processing Record 30 of Set 15 | slyudyanka
# Processing Record 31 of Set 15 | gravdal
# Processing Record 32 of Set 15 | paamiut
# Processing Record 33 of Set 15 | juneau
# Processing Record 34 of Set 15 | watsa
# Processing Record 35 of Set 15 | armidale
# Processing Record 36 of Set 15 | shenkursk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    San Cristobal      VE   7.7669  -72.2250     71.78        99         100
# 1         Tasiilaq      GL  65.6145  -37.6368     32.16        52          14
# 2      New Norfolk      AU -42.7826  147.0587     57.70        45         100
# 3       Vila Velha      BR -20.3297  -40.2925     67.95       100          90
# 4            Paita      PE  -5.0892  -81.1144     65.26        87          70
# 5        Kavaratti      IN  10.5669   72.6420     82.53        81         100
# 6  Arraial Do Cabo      BR -22.9661  -42.0278     67.01        89         100
# 7      Provideniya      RU  64.3833 -173.3000     33.91        80          75
# 8     Kruisfontein      ZA -34.0033   24.7314     53.11        65          53
# 9           Shingu      JP  33.7333  135.9833     79.79        73          44
#
#    Wind Speed Current Description
# 0        1.79     overcast clouds
# 1        4.94          few clouds
# 2        1.99     overcast clouds
# 3        2.30       moderate rain
# 4       12.80       broken clouds
# 5       16.44     overcast clouds
# 6       19.24       moderate rain
# 7       11.18       broken clouds
# 8        6.24       broken clouds
# 9        3.83    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
